# %%
# %pip install azure-identity azure-keyvault-secrets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: azure-identity in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (1.25.1)
# Requirement already satisfied: azure-keyvault-secrets in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (4.10.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-identity) (4.15.0)
# Requirement already satisfied: msal>=1.30.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: azure-core>=1.31.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-identity) (1.38.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: cryptography>=2.5 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-identity) (46.0.3)
# Requirement already satisfied: isodate>=0.6.1 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-keyvault-secrets) (0.7.2)
# Requirement already satisfied: requests>=2.21.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from azure-core>=1.31.0->azure-identity) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (2.23)
# Requirement already satisfied: PyJWT[crypto]<3,>=1.0.0 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from msal>=1.30.0->azure-identity) (2.10.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2025.11.12)
# Requirement already satisfied: idna<4,>=2.5 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.11)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rajatsingh/Library/Python/3.9/lib/python/site-packages (from requests>=2.21.0->azure-core>=1.31.0->azure-identity) (2.6.2)
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from azure.identity import DefaultAzureCredential
from azure.keyvault.secrets import SecretClient

KEY_VAULT_NAME = "DS-KEYS-FOR-WEBAPP"
SECRET_NAME = "password-80"


KEY_VAULT_URL = f"https://{KEY_VAULT_NAME}.vault.azure.net/"

credential = DefaultAzureCredential()
client = SecretClient(vault_url=KEY_VAULT_URL, credential=credential)

secret = client.get_secret(SECRET_NAME)

print("Secret value:", secret.value)
# Out:
# Secret value: Aarav@123

# %%
for i in client.list_properties_of_secrets():
    print(i.name)
# Out:
# ecommercedatalake
# password-80

# %%
for secret_properties in client.list_properties_of_secrets():
    secret_name = secret_properties.name
    secret_value = client.get_secret(secret_name).value

    print(f"{secret_name} = {secret_value}")
# Out:
# ecommercedatalake = kasnfk
# password-80 = Aarav@123
